# %% [markdown]
# # Dates
#
# see:
# - [CVS column Date format (StackOverflow)](https://stackoverflow.com/a/63723564/6312771)

# %%
# import Pkg; Pkg.add("Dates")
using Dates

# %%
example_date = "2020.08.03"
date_format="yyyy.mm.dd"
Date(example_date, "$date_format")
# Out:
# 2020-08-03

# %%
example_date = "2020-08-03"
date_format="yyyy-mm-dd"
Date(example_date, "$date_format")
# Out:
# 2020-08-03

# %%
example_date = "Aug. 3, 2020"
date_format="u. dd, yyyy"
Date(example_date, "$date_format")
# Out:
# 2020-08-03

# %% [markdown]
# # Shifting Date by x days

# %%
today = Date(now())
# Out:
# 2020-09-03

# %%
two_days_ago = today - Dates.Day(2)
# Out:
# 2020-09-01

# %%
today - two_days_ago
# Out:
# 2 days
