# %%
function factorial(num)
    fac=1
    for i in 1:num
        fac=fac*i
    end
    println("The value of factorial is: ", fac)
end
factorial(5)
# Out:
# The value of factorial is: 120

# %%
f(x)=2x^2-4
a=f(2)
println(a)
# Out:
# 4

# %%
using Pkg
Pkg.add("Plots")
using Plots
x=1:10
y=rand(10)
#plot normal
plot(x,y, label=["Dan"])
xlabel!("Valores de x")
ylabel!("Valores de y")
title!("Prueba plot")
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]
