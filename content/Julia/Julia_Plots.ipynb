# %%
## Uncomment the lines below if you have not run it previously
import Pkg; 
Pkg.add("Plots")

using Plots
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
# define the Lorenz attractor
Base.@kwdef mutable struct Lorenz
    dt::Float64 = 0.02
    σ::Float64 = 10
    ρ::Float64 = 28
    β::Float64 = 8/3
    x::Float64 = 1
    y::Float64 = 1
    z::Float64 = 1
end
# Out:
# Lorenz

# %%
function step!(l::Lorenz)
    dx = l.σ * (l.y - l.x);         l.x += l.dt * dx
    dy = l.x * (l.ρ - l.z) - l.y;   l.y += l.dt * dy
    dz = l.x * l.y - l.β * l.z;     l.z += l.dt * dz
end
# Out:
# step! (generic function with 1 method)

# %%
attractor = Lorenz()
# Out:
# Lorenz(0.02, 10.0, 28.0, 2.6666666666666665, 1.0, 1.0, 1.0)

# %%
# initialize a 3D plot with 1 empty series
plt = plot3d(
    1,
    xlim = (-30, 30),
    ylim = (-30, 30),
    zlim = (0, 60),
    title = "Lorenz Attractor",
    marker = 2,
)

# %%
# build an animated gif by pushing new points to the plot, saving every 10th frame
@gif for i=1:1500
    step!(attractor)
    push!(plt, attractor.x, attractor.y, attractor.z)
end every 10
# Out:
# ┌ Info: Saved animation to
# │   fn = /Users/uki/REPOS/UkiDLucas.github.io/src/Julia/tmp.gif
# └ @ Plots /Users/uki/.julia/packages/Plots/8GUYs/src/animation.jl:102
# Plots.AnimatedGif("/Users/uki/REPOS/UkiDLucas.github.io/src/Julia/tmp.gif")

# %% [markdown]
# # Iris Dataset

# %%
# load a dataset
using RDatasets
iris = dataset("datasets", "iris");

# %%
# load the StatsPlots recipes (for DataFrames) available via:
Pkg.add("StatsPlots")
using StatsPlots
# Out:
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]

# %%
# Scatter plot with some custom settings
@df iris scatter(
    :SepalLength,
    :SepalWidth,
    group = :Species,
    title = "Iris dataset",
    xlabel = "Length",
    ylabel = "Width",
    m = (0.5, [:cross :hex :star7], 8),
    bg = RGB(0.2, 0.2, 0.2)
)

# %%
using Plots

# %%
# These are the plotting data 
x = 1:10; 
y = rand(10); 

plot(x,y, label="my label")

# %%
# Package for importing/exporting csv files into/from data frames
using CSV

# Reading a local csv file
data = CSV.read("simple_linear_regression.csv")
# Out:
# 6×3 DataFrame
# │ Row │ i     │ x       │ y       │
# │     │ Int64 │ Float64 │ Float64 │
# ├─────┼───────┼─────────┼─────────┤
# │ 1   │ 1     │ 34.0    │ 5.0     │
# │ 2   │ 2     │ 108.0   │ 17.0    │
# │ 3   │ 3     │ 64.0    │ 11.0    │
# │ 4   │ 4     │ 88.0    │ 8.0     │
# │ 5   │ 5     │ 99.0    │ 14.0    │
# │ 6   │ 6     │ 51.0    │ 5.0     │

# %%
using Plots

# %%
scatter(
    data.x,
    data.y, 
    label="x,y data"
)

# %%
plot(
    data.x,
    data.y, 
    label="x,y data"
)

# %%
bar( 
    data.x,
    data.y, 
    label="x,y data")
