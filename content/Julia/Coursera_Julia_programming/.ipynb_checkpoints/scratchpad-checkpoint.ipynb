# %%
column = 2 # ISM
for row = 1:rows 
    value = array_data[row, column]
    if typeof(value) != Float64 # TODO try catch
        float = 1.0 * value + 0.00001
        array_data[row, column] = float
    end
end
array_data[1:6, :]

# %%
column = 1 # ISM
for row = 1:rows 
    value = array_data[row, column] 
    year_abbrevieated = value[]
    println("orininal ", value)
    year = string("19", value[5:6])
    new_value = string(value[1:3], " ", year)
    println( new_value)
end
array_data[1:6, :]

# %%
column = 3 # 
for row = 3:3:rows-3   # step every 3 rows                           
    value = array_data[row, column] 
    if typeof(value) == Float64                                # TODO try catch   
        #println(row, " ", typeof(value), " ", value)
        array_data[row-0, column] = value
        array_data[row-1, column] = value
        array_data[row-2, column] = value
    end
end
array_data[1:9, :]
# Out:
# UndefVarError: rows not defined
#
# Stacktrace:
#  [1] top-level scope at ./In[1]:2

# %%
for row = 1:rows 
    value = array_data[row, column_dates]
    array_data[row, column_dates] = DateTime(value, date_format)
end
array_data

# %%
#
#using Lathe.preprocess: StandardScalar
#gpd_scaled = StandardScalar(gpd_original)
#Lathe.preprocess.MeanNormalization(gpd_original)

# %%
x = size(gpd_original)
x[1]

length(gpd_original)
