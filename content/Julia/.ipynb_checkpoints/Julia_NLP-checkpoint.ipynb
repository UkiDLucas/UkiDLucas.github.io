# %%
## Uncomment the lines below if you have not run it previously
# import Pkg; 
# Pkg.add("TextAnalysis")

# %%
## Pkg.clone("WordTokenizers")
Pkg.add("WordTokenizers")
# Out:
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#   [796a5d58] + WordTokenizers v0.5.4
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]

# %%
using TextAnalysis
# Out:
# ┌ Info: Precompiling TextAnalysis [a2db99b7-8b79-58f8-94bf-bbc811eef33d]
# └ @ Base loading.jl:1260

# %% [markdown]
# # Ingesting Text

# %%
myStr = "Julia is a high-level, high-performance, dynamic programming language. 
While it is a general purpose language and can be used to write any application, 
many of its features are well-suited for numerical analysis and computational science."
# Out:
# "Julia is a high-level, high-performance, dynamic programming language. \nWhile it is a general purpose language and can be used to write any application, \nmany of its features are well-suited for numerical analysis and computational science."

# %%
strDoc_1 = Document(myStr)
# Out:
# StringDocument{String}("Julia is a high-level, high-performance, dynamic programming language. \nWhile it is a general purpose language and can be used to write any application, \nmany of its features are well-suited for numerical analysis and computational science.", TextAnalysis.DocumentMetadata(Languages.English(), "Untitled Document", "Unknown Author", "Unknown Time"))

# %%
strDoc_2 = StringDocument(myStr)
# Out:
# StringDocument{String}("Julia is a high-level, high-performance, dynamic programming language. \nWhile it is a general purpose language and can be used to write any application, \nmany of its features are well-suited for numerical analysis and computational science.", TextAnalysis.DocumentMetadata(Languages.English(), "Untitled Document", "Unknown Author", "Unknown Time"))

# %%
filePath = "sample.txt"
# Out:
# "sample.txt"

# %%
fileDoc_1 = Document(filePath)
# Out:
# FileDocument("sample.txt", TextAnalysis.DocumentMetadata(Languages.English(), "sample.txt", "Unknown Author", "Unknown Time"))

# %%
fileDoc_2 = FileDocument(filePath)
# Out:
# FileDocument("sample.txt", TextAnalysis.DocumentMetadata(Languages.English(), "sample.txt", "Unknown Author", "Unknown Time"))

# %% [markdown]
# # Document Properties

# %%
text(fileDoc_2)
# Out:
# "Julia is a high-level, high-performance, dynamic programming language. While it is a general purpose language and can be used to write any application, many of its features are well-suited for numerical analysis and computational science."

# %%
language(fileDoc_2)
# Out:
# Languages.English()

# %%
author(fileDoc_2)
# Out:
# "Unknown Author"

# %%
# name(fileDoc_2)
# Out:
# UndefVarError: name not defined
#
# Stacktrace:
#  [1] top-level scope at In[30]:1

# %% [markdown]
# # Tokenization with TextAnalysis

# %%
myTokens = tokens(fileDoc_2)
# Out:
# 39-element Array{String,1}:
#  "Julia"
#  "is"
#  "a"
#  "high-level"
#  ","
#  "high-performance"
#  ","
#  "dynamic"
#  "programming"
#  "language."
#  "While"
#  "it"
#  "is"
#  ⋮
#  "of"
#  "its"
#  "features"
#  "are"
#  "well-suited"
#  "for"
#  "numerical"
#  "analysis"
#  "and"
#  "computational"
#  "science"
#  "."

# %%
myTokens[1]
# Out:
# "Julia"

# %%
poormans_tokenize(fileDoc_2)
# Out:
# UndefVarError: poormans_tokenize not defined
#
# Stacktrace:
#  [1] top-level scope at In[49]:1

# %%
split(text(fileDoc_2))
# Out:
# 35-element Array{SubString{String},1}:
#  "Julia"
#  "is"
#  "a"
#  "high-level,"
#  "high-performance,"
#  "dynamic"
#  "programming"
#  "language."
#  "While"
#  "it"
#  "is"
#  "a"
#  "general"
#  ⋮
#  "many"
#  "of"
#  "its"
#  "features"
#  "are"
#  "well-suited"
#  "for"
#  "numerical"
#  "analysis"
#  "and"
#  "computational"
#  "science."

# %%
import Pkg; Pkg.add("TinySegmenter")
# Out:
#   Resolving package versions...
#    Updating `~/.julia/environments/v1.4/Project.toml`
#  [no changes]
#    Updating `~/.julia/environments/v1.4/Manifest.toml`
#  [no changes]

# %%
# using TinySegmenter
# set_tokenizer(TinySegmenter.tokenize)

# %% [markdown]
# # Split Sentences

# %%
split_sentences(text(fileDoc_2))
# Out:
# UndefVarError: split_sentences not defined
#
# Stacktrace:
#  [1] top-level scope at In[61]:1
